# %%
import pandas as pd
import seaborn as sns
import numpy as np
import re

sns.set(rc={"figure.figsize":[10,10]},font_scale = 1.5)

# %%
E_customers = pd.read_csv("Ecommerce Customers.csv")
E_customers
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
E_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
E_customers.corr()["Yearly Amount Spent"]
# Out:
# Avg. Session Length     0.355088
# Time on App             0.499328
# Time on Website        -0.002641
# Length of Membership    0.809084
# Yearly Amount Spent     1.000000
# Name: Yearly Amount Spent, dtype: float64

# %%
E_customers.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
E_customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
E_customers.isna().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
sns.boxplot(y = "Avg. Session Length" , data = E_customers)
sns.stripplot(y = "Avg. Session Length" , data = E_customers)
# Out:
# <AxesSubplot:ylabel='Avg. Session Length'>

# %%
sns.boxplot(y = "Time on App" , data = E_customers)
sns.stripplot(y = "Time on App" , data = E_customers)
# Out:
# <AxesSubplot:ylabel='Time on App'>

# %%
sns.boxplot(y = "Time on Website" , data = E_customers)
sns.stripplot(y = "Time on Website" , data = E_customers)
# Out:
# <AxesSubplot:ylabel='Time on Website'>

# %%
sns.boxplot(y = "Length of Membership" , data = E_customers)
sns.stripplot(y = "Length of Membership" , data = E_customers)
# Out:
# <AxesSubplot:ylabel='Length of Membership'>

# %%
sns.boxplot(y = "Yearly Amount Spent" , data = E_customers)
sns.stripplot(y = "Yearly Amount Spent" , data = E_customers)
# Out:
# <AxesSubplot:ylabel='Yearly Amount Spent'>

# %%
E_customers.drop(["Email","Address","Avatar"], axis = 1, inplace=True)
E_customers
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %%
E_customers.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
from sklearn.model_selection import train_test_split
x = E_customers.drop("Yearly Amount Spent" , axis = 1)
y = E_customers["Yearly Amount Spent"]
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(x_train)
scaledXtrain = scaler.transform(x_train)
scaledXtest = scaler.transform(x_test)

# %%
models = {
    "LR": LinearRegression(),
    "KNNR" : KNeighborsRegressor(), 
    "SVR": SVR(),
    "DT": DecisionTreeRegressor(),
    "RF": RandomForestRegressor(),
    "XGBR": XGBRegressor()
}

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Test Score: {model.score(x_test, y_test)}') 
    y_pred = model.predict(x_test)
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')
    print('-----------------------------------------------------------')
# Out:
# Using model: LR
# Training Score: 0.9846672470413471
# Test Score: 0.982437813722246
# RMSE: 10.07960124597572
# -----------------------------------------------------------
# Using model: KNNR
# Training Score: 0.9422164445277718
# Test Score: 0.8886409161710626
# RMSE: 25.38147673996786
# -----------------------------------------------------------
# Using model: SVR
# Training Score: 0.01983864589845219
# Test Score: 0.020386157827549822
# RMSE: 75.28033074230463
# -----------------------------------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 0.8494858482386864
# RMSE: 29.50820076535822
# -----------------------------------------------------------
# Using model: RF
# Training Score: 0.9915997737810633
# Test Score: 0.9319695016941066
# RMSE: 19.83836552439305
# -----------------------------------------------------------
# Using model: XGBR
# Training Score: 0.9999829732186143
# Test Score: 0.9296208575233647
# RMSE: 20.17790380937585
# ...

# %%
import joblib

# %%
joblib.dump(model, 'model.h5')
# Out:
# ['model.h5']

# %%
joblib.dump(scaler, 'scaler.h5')
# Out:
# ['scaler.h5']

# %%
E_customers
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %%
x.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership'],
#       dtype='object')

# %%
test = [34,11,38,3]

# %%
test = scaler.transform([test])

# %%
model.predict(test)
# Out:
# array([224.34103], dtype=float32)
